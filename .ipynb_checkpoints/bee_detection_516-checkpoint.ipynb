# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive
# Out:
# /content/drive

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# 'Aurélien Géron - Hands-on Machine Learning with Scikit-Learn and TensorFlow-O’Reilly (2017).pdf'
#  BeeDetection_yolo.ipynb
#  best.pt
# 'Colab Notebooks'/
#  data/
#  data_prep/
#  detect.py
#  facimotion.gslides
#  fer.csv
# 'Hey check out.txt'
#  IMG_20221027_121753.jpg
#  Machine-Learning-A-Z-Course-Downloadable-Slides-V1.1.pdf
# 'mid term report on facImotion.gdoc'
#  Photos-SM/
#  putty-64bit-0.78-installer.msi
#  Tihar/
# 'Tilicho Camera'/
# 'Untitled spreadsheet.gsheet'
#  VID_20220928_155931.mp4
#  Video/
#  yolo/
#  yolo1/

# %%
cd yolo1
# Out:
# /content/drive/MyDrive/yolo1

# %%
cd yolov5
# Out:
# /content/drive/MyDrive/yolo1/yolov5

# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14995, done.
# remote: Total 14995 (delta 0), reused 0 (delta 0), pack-reused 14995
# Receiving objects: 100% (14995/14995), 14.08 MiB | 11.01 MiB/s, done.
# Resolving deltas: 100% (10280/10280), done.

# %%
import pandas as pd
import os
import glob
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split
import shutil
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
import PIL

# %%
# !python train.py --img 640 --cfg yolov5m.yaml --hyp data/hyps/hyp.scratch-med.yaml --batch 32 --epochs 200 --data bee_detection.yaml --weights yolov5m.pt --workers 4 --name yolo_bee_detection_m
# Out:
# train: weights=yolov5m.pt, cfg=yolov5m.yaml, data=bee_detection.yaml, hyp=data/hyps/hyp.scratch-med.yaml, epochs=200, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=4, project=runs/train, name=yolo_bee_detection_m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-71-gc442a2e Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --source bee_detection/images/valid/ --weights runs/train/yolo_bee_detection_m5/weights/best.pt --max-det 3  --conf-thres 0.005 --classes 0 --name bee_detected
# Out:
# detect: weights=['runs/train/yolo_bee_detection_m5/weights/best.pt'], source=bee_detection/images/valid/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.005, iou_thres=0.45, max_det=3, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=bee_detected, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirements "gitpython" "ipython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 35.8 MB/s eta 0:00:00
# ...
#
# ...
